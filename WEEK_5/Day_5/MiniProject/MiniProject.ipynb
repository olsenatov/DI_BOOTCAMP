# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Part 1

# %%
#1
boston_housing = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')

# %%
boston_housing
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
#2
boston_housing.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
boston_housing.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
boston_housing.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
boston_housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
boston_housing.isnull().sum()
# Out:
# crim             0
# zn               0
# indus            0
# chas             0
# nox              0
# rm               0
# age              0
# dis              0
# rad              0
# tax              0
# ptratio          0
# b                0
# lstat            0
# medv             0
# NewFeature       0
# age_category    43
# dtype: int64

# %%
plt.figure(figsize = (12,8))
boston_housing.hist(bins = 30, figsize = (12,8))
plt.tight_layout()

# %%
plt.figure(figsize=(12, 8))
sns.pairplot(boston_housing, hue = 'medv', x_vars=boston_housing.columns[:-1], y_vars=['medv'])
plt.tight_layout()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /var/folders/8k/7mvddsf91sq0mgwbv7_bb9nc0000gn/T/ipykernel_90260/239151479.py:3: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
boston_housing.min()
# Out:
# crim         0.00632
# zn           0.00000
# indus        0.46000
# chas         0.00000
# nox          0.38500
# rm           3.56100
# age          2.90000
# dis          1.12960
# rad          1.00000
# tax        187.00000
# ptratio     12.60000
# b            0.32000
# lstat        1.73000
# medv         5.00000
# dtype: float64

# %%
boston_housing_norm = (boston_housing[:-1] - np.min(boston_housing[:-1])) / (np.max(boston_housing[:-1]) - np.min(boston_housing[:-1]))

# %%
boston_housing_norm
# Out:
#          crim        zn     indus  chas       nox        rm       age  \
# 0    0.000009  0.025316  0.003249   0.0  0.000757  0.009248  0.091702
# 1    0.000038  0.000000  0.009944   0.0  0.000660  0.009031  0.110970
# 2    0.000038  0.000000  0.009944   0.0  0.000660  0.010105  0.085935
# 3    0.000046  0.000000  0.003066   0.0  0.000644  0.009842  0.064416
# 4    0.000097  0.000000  0.003066   0.0  0.000644  0.010052  0.076231
# ..        ...       ...       ...   ...       ...       ...       ...
# 501  0.000088  0.000000  0.016779   0.0  0.000806  0.009273  0.097187
# 502  0.000064  0.000000  0.016779   0.0  0.000806  0.008608  0.107876
# 503  0.000085  0.000000  0.016779   0.0  0.000806  0.009812  0.127989
# 504  0.000154  0.000000  0.016779   0.0  0.000806  0.009556  0.125598
# 505  0.000067  0.000000  0.016779   0.0  0.000806  0.008481  0.113643
#
#           dis       rad       tax   ptratio         b     lstat      medv
# ...

# %%
#4
#create a column that is varchar that compares age to young (<= 30), middleage(>= 30 or <= 60), old (>= 60) variables
age_labels = ['new','middle','old']
boston_housing['age_category'] = pd.cut(boston_housing['age'],bins=[0.0,30.0,60.0,101.0],labels= age_labels, right = False)

boston_housing
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv  NewFeature age_category
# 0       15.3  396.90   4.98  24.0    32.74350          old
# ...

# %%
#5
# corr1 = boston_housing['crim'].corr(boston_housing['medv'])
# corr2 = boston_housing['zn'].corr(boston_housing['medv'])
# corr3 = 
correlations = []
for column in boston_housing[:-1]:
    correlations.append(boston_housing[column].corr(boston_housing['medv']))

# %%
correlations
# Out:
# [-0.3883046085868113,
#  0.36044534245054277,
#  -0.4837251600283727,
#  0.17526017719029854,
#  -0.42732077237328264,
#  0.6953599470715395,
#  -0.3769545650045963,
#  0.24992873408590388,
#  -0.38162623063977763,
#  -0.468535933567767,
#  -0.5077866855375617,
#  0.33346081965706653,
#  -0.7376627261740147,
#  1.0]

# %%
sns.heatmap(boston_housing.corr())
# Out:
# <Axes: >

# %%
#6
boston_housing['NewFeature'] = boston_housing['rm'] * boston_housing['lstat']

# %%
boston_housing.head(5)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv  NewFeature age_category
# 0  396.90   4.98  24.0    32.74350          old
# 1  396.90   9.14  21.6    58.68794          old
# 2  392.83   4.03  34.7    28.95555          old
# 3  394.63   2.94  33.4    20.57412   middle age
# 4  396.90   5.33  36.2    38.09351   middle age

# %% [markdown]
# ## Part 2

# %%
new_properties = boston_housing[boston_housing['age'] <= 35.0]
middle_properties = boston_housing[(boston_housing['age'] > 35.0) & (boston_housing['age'] <= 70.0)]
old_properties = boston_housing[boston_housing['age'] > 70.0]
plt.figure(figsize=(10, 6))

plt.hist(new_properties['medv'], bins=20, alpha=1.0, label='New Properties')
plt.hist(middle_properties['medv'], bins=20, alpha=0.8, label='Middle Properties')
plt.hist(old_properties['medv'], bins=20, alpha=0.4, label='Old Properties')

plt.xlabel('Median Value (MEDV)')
plt.ylabel('Frequency')
plt.title('Property Age vs. Median Value')
plt.legend()
plt.show()

# %% [markdown]
# ## Part 3

# %%
boston_housing['crim'] = pd.cut(boston_housing['crim'], bins=[0, 1, 5, 10, 20, max(boston_housing['crim'])],
                        labels=['0-1', '1-5', '5-10', '10-20', '20+'])

# %%
boston_housing['crim']
# Out:
# 0      0-1
# 1      0-1
# 2      0-1
# 3      0-1
# 4      0-1
#       ...
# 501    0-1
# 502    0-1
# 503    0-1
# 504    0-1
# 505    0-1
# Name: crim, Length: 506, dtype: category
# Categories (5, object): ['0-1' < '1-5' < '5-10' < '10-20' < '20+']

# %%
avg_medv_per_crim_bin = boston_housing.groupby('crim')['medv'].mean()

# %%
avg_medv_per_crim_bin
# Out:
# crim
# 0-1      25.110843
# 1-5      21.469118
# 5-10     18.048077
# 10-20    13.694444
# 20+       9.633333
# Name: medv, dtype: float64

# %%
plt.figure(figsize=(10, 6))
avg_medv_per_crim_bin.plot(kind='line', marker='o', color='b')

plt.xlabel('Binned Crime Rate')
plt.ylabel('Average MEDV')
plt.title('Impact of Neighborhood Crime Rate on Prices')
plt.xticks(rotation=45)
plt.grid(True)

plt.tight_layout()
plt.show()
